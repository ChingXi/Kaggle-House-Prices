# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_train = pd.read_csv('train.csv')
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
x = df_train['YearBuilt']
y = df_train['SalePrice']
data = pd.concat([x, y], axis=1)
data.plot.scatter(x = 'YearBuilt', y = 'SalePrice');

# %%
x = df_train['GrLivArea']
y = df_train['SalePrice']
data = pd.concat([x, y], axis=1)
data.plot.scatter(x = 'GrLivArea', y = 'SalePrice');

# %%
sns.boxplot(x=df_train['OverallQual'], y=df_train['SalePrice']);

# %%
sns.boxplot(x=df_train['OverallCond'], y=df_train['SalePrice']);

# %%
corrmat = df_train.corr()
corrmat
# Out:
# C:\Users\97gwm0\AppData\Local\Temp\ipykernel_22380\940836435.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df_train.corr()
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# ...

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corrmat, cmap='coolwarm', vmax = 0.8)
# Out:
# <AxesSubplot: >

# %%
corr = np.corrcoef((df_train['SalePrice'], df_train['OverallQual'], df_train['TotalBsmtSF'], df_train['GrLivArea'], df_train['GarageCars']))
corr
# Out:
# array([[1.        , 0.7909816 , 0.61358055, 0.70862448, 0.6404092 ],
#        [0.7909816 , 1.        , 0.5378085 , 0.59300743, 0.60067072],
#        [0.61358055, 0.5378085 , 1.        , 0.4548682 , 0.43458483],
#        [0.70862448, 0.59300743, 0.4548682 , 1.        , 0.46724742],
#        [0.6404092 , 0.60067072, 0.43458483, 0.46724742, 1.        ]])

# %%
cols = corrmat.nlargest(10, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df_train[cols].values.T)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
